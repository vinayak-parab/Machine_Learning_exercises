# %% [markdown]
# 1) DATA LOADING

# %%
import pandas as pd
print("ibraries imported")
# Out:
# ibraries imported

# %%
df = pd.read_csv("prisoners.csv")
print("file loaded successfully")
# Out:
# file loaded successfully

# %%
# load the first 5 rows
df.head(5)
# Out:
#             STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 0     Andhra Pradesh  2013                                               9480
# 1  Arunachal Pradesh  2013                                                  0
# 2              Assam  2013                                                676
# 3              Bihar  2013                                               1693
# 4        Chhatisgarh  2013                                               1664
#
#    No. of Inmates benefitted by Adult Education  \
# 0                                         13758
# 1                                             0
# 2                                           750
# 3                                          3013
# 4                                          1803
#
#    No. of Inmates benefitted by Higher Education  \
# 0                                            672
# 1                                              0
# 2                                             14
# 3                                            125
# 4                                            192
#
#    No. of Inmates benefitted by Computer Course
# 0                                           170
# 1                                             0
# 2                                            30
# 3                                          1417
# 4                                           103

# %%
# load the last 5 rows
df.tail(5)
# Out:
#         STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 30  D & N Haveli  2013                                                  0
# 31   Daman & Diu  2013                                                  0
# 32         Delhi  2013                                               1458
# 33   Lakshadweep  2013                                                  0
# 34   Pondicherry  2013                                                  0
#
#     No. of Inmates benefitted by Adult Education  \
# 30                                             0
# 31                                             0
# 32                                          1187
# 33                                             0
# 34                                             0
#
#     No. of Inmates benefitted by Higher Education  \
# 30                                              0
# 31                                              0
# 32                                            908
# 33                                              0
# 34                                              0
#
#     No. of Inmates benefitted by Computer Course
# 30                                             0
# 31                                             0
# 32                                           174
# 33                                             0
# 34                                             0

# %%
df.head()
# Out:
#             STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 0     Andhra Pradesh  2013                                               9480
# 1  Arunachal Pradesh  2013                                                  0
# 2              Assam  2013                                                676
# 3              Bihar  2013                                               1693
# 4        Chhatisgarh  2013                                               1664
#
#    No. of Inmates benefitted by Adult Education  \
# 0                                         13758
# 1                                             0
# 2                                           750
# 3                                          3013
# 4                                          1803
#
#    No. of Inmates benefitted by Higher Education  \
# 0                                            672
# 1                                              0
# 2                                             14
# 3                                            125
# 4                                            192
#
#    No. of Inmates benefitted by Computer Course
# 0                                           170
# 1                                             0
# 2                                            30
# 3                                          1417
# 4                                           103

# %%
df.describe()
# Out:
#          YEAR  No. of Inmates benefitted by Elementary Education  \
# count    35.0                                          35.000000
# mean   2013.0                                        1057.914286
# std       0.0                                        2078.196777
# min    2013.0                                           0.000000
# 25%    2013.0                                           0.000000
# 50%    2013.0                                         167.000000
# 75%    2013.0                                        1294.500000
# max    2013.0                                        9480.000000
#
#        No. of Inmates benefitted by Adult Education  \
# count                                     35.000000
# mean                                    1534.857143
# std                                     3022.110503
# min                                        0.000000
# 25%                                        6.500000
# 50%                                      237.000000
# 75%                                     1733.500000
# max                                    13758.000000
#
#        No. of Inmates benefitted by Higher Education  \
# count                                      35.000000
# mean                                      237.457143
# std                                       375.614191
# min                                         0.000000
# 25%                                         2.000000
# 50%                                        33.000000
# 75%                                       234.500000
# max                                      1353.000000
#
#        No. of Inmates benefitted by Computer Course
# count                                     35.000000
# mean                                     210.171429
# std                                      359.117340
# min                                        0.000000
# 25%                                        0.000000
# 50%                                       38.000000
# 75%                                      227.500000
# max                                     1417.000000

# %%
# renaming the columns 
df1= df.rename(columns={'No. of Inmates benefitted by Elementary Education':'num_elmedu','No. of Inmates benefitted by Adult Education':'num_adultedu',
                    'No. of Inmates benefitted by Higher Education':'num_highedu','No. of Inmates benefitted by Computer Course':'num_comp'})

# %%
df1
# Out:
#              STATE/UT  YEAR  num_elmedu  num_adultedu  num_highedu  num_comp
# 0      Andhra Pradesh  2013        9480         13758          672       170
# 1   Arunachal Pradesh  2013           0             0            0         0
# 2               Assam  2013         676           750           14        30
# 3               Bihar  2013        1693          3013          125      1417
# 4         Chhatisgarh  2013        1664          1803          192       103
# 5                 Goa  2013           7             0            6        88
# 6             Gujarat  2013        2310          3133          875       966
# 7             Haryana  2013        1131           774         1112       243
# 8    Himachal Pradesh  2013          33            80           26         0
# 9     Jammu & Kashmir  2013         102           124           33        34
# 10          Jharkhand  2013        3008          2595          138       574
# 11          Karnataka  2013         633           568          170        12
# 12             Kerala  2013         156            96           24       250
# 13     Madhya Pradesh  2013        1978          9574          301       151
# 14        Maharashtra  2013         346          2743          882      1330
# 15            Manipur  2013           0             0            0         0
# 16          Meghalaya  2013           1            30            0         0
# 17            Mizoram  2013           0            25           18         0
# 18           Nagaland  2013           0             0            0         0
# 19             Orissa  2013         622           613          277       384
# 20             Punjab  2013         325           606          112       168
# 21          Rajasthan  2013        1050           237           64        38
# 22             Sikkim  2013           0             0            0         0
# 23          Tamilnadu  2013          68          1664          757       478
# 24            Tripura  2013          15            13            4         2
# 25      Uttar Pradesh  2013        7876          8093         1353       212
# 26        Uttaranchal  2013         205            42           29        72
# 27        West Bengal  2013        2023          1889          123       460
# 28      A & N Islands  2013         167            45           11         0
# 29         Chandigarh  2013           0           265           85         0
# 30       D & N Haveli  2013           0             0            0         0
# 31        Daman & Diu  2013           0             0            0         0
# 32              Delhi  2013        1458          1187          908       174
# 33        Lakshadweep  2013           0             0            0         0
# 34        Pondicherry  2013           0             0            0         0

# %%
# There are below 8 cities where the total number of inmates benefitted by education is 0
# please run the below line of code
df1.loc[((df1['num_elmedu'] == 0) & (df1['num_adultedu'] == 0) & (df1['num_highedu'] == 0) & (df1['num_comp'] == 0))]
# Out:
#              STATE/UT  YEAR  num_elmedu  num_adultedu  num_highedu  num_comp
# 1   Arunachal Pradesh  2013           0             0            0         0
# 15            Manipur  2013           0             0            0         0
# 18           Nagaland  2013           0             0            0         0
# 22             Sikkim  2013           0             0            0         0
# 30       D & N Haveli  2013           0             0            0         0
# 31        Daman & Diu  2013           0             0            0         0
# 33        Lakshadweep  2013           0             0            0         0
# 34        Pondicherry  2013           0             0            0         0

# %% [markdown]
# 2) DATA MANIPULATION

# %%
df2 = df1.drop(['YEAR'], axis=1)

# %%
df2['totalbenefitted'] = df2.sum(axis=1)

# %%
df2
# Out:
#              STATE/UT  num_elmedu  num_adultedu  num_highedu  num_comp  \
# 0      Andhra Pradesh        9480         13758          672       170
# 1   Arunachal Pradesh           0             0            0         0
# 2               Assam         676           750           14        30
# 3               Bihar        1693          3013          125      1417
# 4         Chhatisgarh        1664          1803          192       103
# 5                 Goa           7             0            6        88
# 6             Gujarat        2310          3133          875       966
# 7             Haryana        1131           774         1112       243
# 8    Himachal Pradesh          33            80           26         0
# 9     Jammu & Kashmir         102           124           33        34
# 10          Jharkhand        3008          2595          138       574
# 11          Karnataka         633           568          170        12
# 12             Kerala         156            96           24       250
# 13     Madhya Pradesh        1978          9574          301       151
# 14        Maharashtra         346          2743          882      1330
# 15            Manipur           0             0            0         0
# 16          Meghalaya           1            30            0         0
# 17            Mizoram           0            25           18         0
# 18           Nagaland           0             0            0         0
# 19             Orissa         622           613          277       384
# 20             Punjab         325           606          112       168
# 21          Rajasthan        1050           237           64        38
# 22             Sikkim           0             0            0         0
# 23          Tamilnadu          68          1664          757       478
# 24            Tripura          15            13            4         2
# 25      Uttar Pradesh        7876          8093         1353       212
# 26        Uttaranchal         205            42           29        72
# 27        West Bengal        2023          1889          123       460
# 28      A & N Islands         167            45           11         0
# 29         Chandigarh           0           265           85         0
# 30       D & N Haveli           0             0            0         0
# 31        Daman & Diu           0             0            0         0
# 32              Delhi        1458          1187          908       174
# 33        Lakshadweep           0             0            0         0
# 34        Pondicherry           0             0            0         0
#
#     totalbenefitted
# 0             24080
# 1                 0
# 2              1470
# 3              6248
# 4              3762
# 5               101
# 6              7284
# 7              3260
# 8               139
# 9               293
# 10             6315
# 11             1383
# 12              526
# 13            12004
# 14             5301
# 15                0
# 16               31
# 17               43
# 18                0
# 19             1896
# 20             1211
# 21             1389
# 22                0
# 23             2967
# 24               34
# 25            17534
# 26              348
# 27             4495
# 28              223
# 29              350
# 30                0
# 31                0
# 32             3727
# 33                0
# 34                0

# %%
df3 = df2.drop(['totalbenefitted','STATE/UT'], axis=1)
# x = df3.sum(axis=0)
# print(type(x))
# print(x)
df3.sum(axis=0)
# Out:
# num_elmedu      37027
# num_adultedu    53720
# num_highedu      8311
# num_comp         7356
# dtype: int64

# %% [markdown]
# 3) Plotting

# %%
import matplotlib.pyplot as plt
print("imported successfully")
# Out:
# imported successfully

# %%
df2.plot.bar(x='STATE/UT', y='totalbenefitted', rot=90)
